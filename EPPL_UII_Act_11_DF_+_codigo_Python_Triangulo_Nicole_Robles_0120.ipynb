# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolerobles128/EPPL-Area-de-un-triangulo-mis-imagenes/blob/main/EPPL_UII_Act_11_DF_%2B_codigo_Python_Triangulo_Nicole_Robles_0120.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Nicole Robles NL=46 Fecha 25/03/2026 ⚡
# ---
# # Calcular el área y perímetro de un triangulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/nicolerobles128/EPPL-Area-de-un-triangulo-mis-imagenes/3e88b04bcd5dfc40c20c3863bb56e0784cd59396/Area%20Triangulo.PNG)
#
# ## Formula para calcular Area
# * $b*h/2
#
#
# ## Datos de entrada
# * $b$ ?
# * $h$ ?
#
# ## Diagrama de flujo en lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/nicolerobles128/EPPL-Area-de-un-triangulo-mis-imagenes/3e37d1b6b1900f85c4ec4b9c999c52c265c4f7f2/DF%20Area%20Triangulo.PNG)

# %%
# Calcular area de un triangulo rectangulo
# Variables A, b, h
# Formula A = (b * h) / 2
# Capturar los valores de b y h
import math
print("Calcular area de un triangulo rectangulo")
b = float(input("Ingrese el valor de la base: "))
h = float(input("Ingrese el valor de la altura: "))
A = (b * h) / 2
print("El area del triangulo es: ", A)
print("Nicole Robles NL = 46")
# Out:
# Calcular area de un triangulo rectangulo
# Ingrese el valor de la base: 8
# Ingrese el valor de la altura: 5
# El area del triangulo es:  20.0
# Nicole Robles NL = 46

# %% [markdown]
# ## Relacion entre codigo y DF en tellegram
# ![Logo de Markdown](https://raw.githubusercontent.com/nicolerobles128/EPPL-Area-de-un-triangulo-mis-imagenes/0c8cf65e9a65567796fa87e27965cc502587b6e4/Codigo%20DF.PNG)
